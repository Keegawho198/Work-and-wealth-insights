# %%
## Project 4 HELLO

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

file_path = "/content/gdrive/My Drive/Colab Notebooks/Project 4/labour_data.csv"

# Read the CSV file
df = pd.read_csv(file_path)

# Display the first few rows
df
# Out:
#      STRUCTURE   STRUCTURE_ID STRUCTURE_NAME ACTION MEASURE  \
# 0     DATAFLOW  ABS:LF(1.0.0)   Labour Force      I      M4
# 1     DATAFLOW  ABS:LF(1.0.0)   Labour Force      I      M4
# 2     DATAFLOW  ABS:LF(1.0.0)   Labour Force      I      M4
# 3     DATAFLOW  ABS:LF(1.0.0)   Labour Force      I      M4
# 4     DATAFLOW  ABS:LF(1.0.0)   Labour Force      I      M4
# ...        ...            ...            ...    ...     ...
# 6715  DATAFLOW  ABS:LF(1.0.0)   Labour Force      I     M12
# 6716  DATAFLOW  ABS:LF(1.0.0)   Labour Force      I     M12
# 6717  DATAFLOW  ABS:LF(1.0.0)   Labour Force      I     M12
# 6718  DATAFLOW  ABS:LF(1.0.0)   Labour Force      I     M12
# 6719  DATAFLOW  ABS:LF(1.0.0)   Labour Force      I     M12
#
#                                       Measure  SEX      Sex   AGE  \
# 0     Unemployed - looking for full-time work    3  Persons  1599
# 1     Unemployed - looking for full-time work    3  Persons  1599
# ...

# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# Define the correct file path
file_path = "/content/gdrive/My Drive/Colab Notebooks/Project 4/proj4.xlsx"

# Read the Excel file
df = pd.read_excel(file_path)

# Display the first few rows
df.head(10)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#                            Time Period  Time Period.1     Jan 2015  \
# 0                               Region            NaN          NaN
# 1  Measure: Employed - full-time 3,NUM            NaN          NaN
# 2                            Australia            NaN  8006.548693
# 3                   ·  New South Wales            NaN  2515.497235
# 4                          ·  Victoria            NaN  1982.947992
# 5                        ·  Queensland            NaN  1613.553270
# 6  Measure: Employed - part-time 3,NUM            NaN          NaN
# 7                            Australia            NaN  3460.832389
# 8                   ·  New South Wales            NaN  1061.367495
# 9                          ·  Victoria            NaN   950.364979
#
#       Feb 2015     Mar 2015     Apr 2015     May 2015     Jun 2015  \
# ...

# %%
# swap rows and coloumns
df_transposed = df.T
df_transposed.head(10)  # Display first few rows after transpose
# Out:
#                    0                                    1            2   \
# Time Period    Region  Measure: Employed - full-time 3,NUM    Australia
# Time Period.1     NaN                                  NaN          NaN
# Jan 2015          NaN                                  NaN  8006.548693
# Feb 2015          NaN                                  NaN  8152.775102
# Mar 2015          NaN                                  NaN  8076.976091
# Apr 2015          NaN                                  NaN  8057.650037
# May 2015          NaN                                  NaN  8109.094238
# Jun 2015          NaN                                  NaN  8085.321035
# Jul 2015          NaN                                  NaN  8147.506533
# Aug 2015          NaN                                  NaN  8051.751352
#
#                                3            4              5   \
# Time Period    ·  New South Wales  ·  Victoria  ·  Queensland
# ...

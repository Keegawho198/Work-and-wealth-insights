# %%
#for testing

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# Define the correct file path
file_path = "/content/gdrive/My Drive/Colab Notebooks/Project 4/employed persons.xlsx"

# Read the Excel file
df = pd.read_excel(file_path)

# Display the first few rows
df.head(10)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#          Juristiction      Jan 2015      Feb 2015      Mar 2015      Apr 2015  \
# 0           Australia  11467.381082  11724.132317  11698.200691  11711.507459
# 1  ·  New South Wales   3576.864731   3658.479105   3678.204067   3692.872468
# 2         ·  Victoria   2933.312971   3006.573772   2985.656739   2984.184983
# 3       ·  Queensland   2279.415481   2337.504349   2310.542932   2323.236201
#
#        May 2015      Jun 2015      Jul 2015      Aug 2015      Sep 2015  ...  \
# 0  11781.440931  11752.901484  11759.912065  11702.631255  11771.038677  ...
# 1   3689.135866   3702.717647   3724.732059   3708.785165   3742.266380  ...
# 2   3002.150251   2990.410979   2992.233671   2960.394067   2977.571284  ...
# 3   2347.679514   2341.763097   2335.414813   2333.997699   2355.227468  ...
#
# ...

# %%
# swap rows and coloumns
df_transposed = df.T
df_transposed.head(10)  # Display first few rows after transpose
# Out:
#                          0                   1            2              3
# Juristiction     Australia  ·  New South Wales  ·  Victoria  ·  Queensland
# Jan 2015      11467.381082         3576.864731  2933.312971    2279.415481
# Feb 2015      11724.132317         3658.479105  3006.573772    2337.504349
# Mar 2015      11698.200691         3678.204067  2985.656739    2310.542932
# Apr 2015      11711.507459         3692.872468  2984.184983    2323.236201
# May 2015      11781.440931         3689.135866  3002.150251    2347.679514
# Jun 2015      11752.901484         3702.717647  2990.410979    2341.763097
# Jul 2015      11759.912065         3724.732059  2992.233671    2335.414813
# Aug 2015      11702.631255         3708.785165  2960.394067    2333.997699
# Sep 2015      11771.038677          3742.26638  2977.571284    2355.227468
# No charts were generated by quickchart

# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# Define the correct file path
file_path = "/content/gdrive/My Drive/Colab Notebooks/Project 4/Resources/civpopulation.xlsx"

# Read the Excel file
civ_df = pd.read_excel(file_path)

# Display the first few rows
civ_df.head(10)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#          Juristiction   Jan 2015   Feb 2015   Mar 2015   Apr 2015   May 2015  \
# 0           Australia  19139.039  19168.578  19198.121  19217.447  19236.772
# 1  ·  New South Wales   6128.753   6138.316   6147.852   6153.574   6159.322
# 2         ·  Victoria   4865.823   4876.232   4886.630   4893.998   4901.365
# 3       ·  Queensland   3795.544   3800.554   3805.594   3809.321   3813.034
#
#     Jun 2015   Jul 2015   Aug 2015   Sep 2015  ...      Mar 2024  \
# 0  19256.097  19279.582  19303.061  19326.545  ...  22260.174005
# 1   6165.052   6172.896   6180.750   6188.593  ...   6957.259001
# 2   4908.734   4917.887   4927.037   4936.189  ...   5736.178001
# 3   3816.752   3820.703   3824.647   3828.601  ...   4539.249001
#
#        Apr 2024      May 2024      Jun 2024      Jul 2024      Aug 2024  \
# ...

# %%
# swap rows and coloumns
civ_transposed = civ_df.T
civ_transposed.head(10)  # Display first few rows after transpose
# Out:
#                       0                   1            2              3
# Juristiction  Australia  ·  New South Wales  ·  Victoria  ·  Queensland
# Jan 2015      19139.039            6128.753     4865.823       3795.544
# Feb 2015      19168.578            6138.316     4876.232       3800.554
# Mar 2015      19198.121            6147.852      4886.63       3805.594
# Apr 2015      19217.447            6153.574     4893.998       3809.321
# May 2015      19236.772            6159.322     4901.365       3813.034
# Jun 2015      19256.097            6165.052     4908.734       3816.752
# Jul 2015      19279.582            6172.896     4917.887       3820.703
# Aug 2015      19303.061             6180.75     4927.037       3824.647
# Sep 2015      19326.545            6188.593     4936.189       3828.601
